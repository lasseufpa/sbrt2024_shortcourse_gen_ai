# %% [markdown]
# ## SBrT 2024 - **An Introduction to Generative Artificial Intelligence with Applications in Telecommunications**

# %% [markdown]
# This notebook is based on the code of the repository at [https://github.com/karpathy/char-rnn/](https://github.com/karpathy/char-rnn/).
#
# The goal of this notebook is to show an application using multilayer RNN that learns to predict the next word of a text.

# %% [markdown]
# ## Load Modules

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=a5d686cb44c5e9e4c9ec761594299ecc7749ebf74cae9349b99753fa2c696365
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import numpy as np
import wget

# %% [markdown]
# ## Load data

# %%
dataset_url = 'https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt'
wget.download(dataset_url)

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115394 characters, 65 unique.

# %% [markdown]
# ## Set model hyperparameters

# %%
# hyperparameters
hidden_size = 20 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %% [markdown]
# ## Set model parameters

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %% [markdown]
# ## Loss Function

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# ## Get a sample

# %%
def sample(h, seed_ix, n):
  """
  sample a sequence of integers from the model
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %% [markdown]
# ## Training the model

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0:
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by],
                                [dWxh, dWhh, dWhy, dbh, dby],
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  $-vv?fqJHbm3EEW,AbHSQco.u&KK
# Y
# mmdDULSFX
# o;zLIgAY FMHT;apHQRKUBrgirHu$GtizLpZX;oFcmwN&CL!Pe; :gwxsk,
# F rLf$T;HEExRFJio;ydLQ:lRRu,aXIP-;Cnc.iuV:O LvFj$V;R.hf$HoIMb!$j
# M!WSIqfD3SmDj?3OUxO
# BwTbvjUiVZ-m-?
# ----
# iter 0, loss: 104.359685
# ----
#  a
# bat aaae rsc bi sousenorbe; ndishoutysd whayhet tireyaSilen
# A: hem niee ce nhar fhet ne
# pe'
#
# Qhotsd the. hh n itizsd fimlt thenh anbves boboie dek ht ura onimathah. ehhtr yien chrt vareronot whorrer
# ----
# iter 100, loss: 101.463173
# ----
#  r taesd the ithe tit yout oenpardesers Whe fit
# Ohe mendUWtleroms doul
# Wenrtat anPtnaWhe a cotr il mild gre'sg't stomsf corse fonalen:
# y, miend pof whe,, you heke meC
# Sirf
# theramyg the bumtssalhe banss
# ----
# iter 200, loss: 98.072405
# ----
#  e oo'r? toficon, inallc.
# Tfopar ouo, yisf o?
# Heg io,
# Thitizm nd mrast bins-iboUA? Wie
#
# M3Wgamy, Cio,
# C
# Thot,
# Iy fecir Cat' dousuR the this cf ion, thist waracire aand rhe woct lo tsyyucoaln:
# Thae po z
# ----
# iter 300, loss: 94.484044
# ----
#  no gure magh wious ang hufhel's syath bauiu sorot
# zermr ss and
# Af ar pjwandor bome!
# yoo,,yYlend sod ibhir AnN the sirag und sineusd loved wors;
# Afe fobround oret weou hethe wyor whiog
#
# Mf:Al,
# Yob thu
# ----
# iter 400, loss: 91.273521
# ----
#   tron thicuses wor sinl
# Bat; hiud ghe te ballcpth theelamny.
# Th Me beist tha lo ceas muso mtirit,dewe heinsirdenss'lgsiny eat woun wasle ho opel. atnot te fals,
# Tt
# BunV 'o
# fununle lat oris, helven,
# W
# ----
# iter 500, loss: 88.339207
# ----
#  k t mel.or that? Mg fhr havetirs, aat kusthefavere nn'e tesr'qisl busties cot hiee pehalc oled mh ampe enmCanther hell Rmens cherurms
# Tonderoe sforr tht boreird yon Tourmikl:
#
# Mu'l
# Wot aaburs
#
# hes.
#
# M
# ----
# iter 600, loss: 85.653625
# ----
#  e tyns be?e-youse oateouns ons an, he 'th t han, Oad. Tiphel fadeald o' Romer me mel, ang l't Cating smanmerge qurVI roedikn:
# Veghom
# Oeamt andc s e yid'n
#
# fha myur mors at at me tiss.
#
# Azz:
# Sir yot he
# ----
# iter 700, loss: 83.470533
# ----
#  hit dis wond Bli.
#
# MAD:
# Ib:
# ONind 'w hert hy, titcit .
# O
# OIC:
# LI
# llBtid If mo geou heth lme, ge'w!
#
# VuTet.
# IA: oe.d le, pos; verose betisl
#
# Fiecawor, you her.
# M
# CI
# NKIA:
# Ve soed naliny nof nke ves fio
# ----
# iter 800, loss: 80.920154
# ----
#   Ale foweed fadkter tme. I
#
# Wole smons nomt l stod hes itisw'se vect ield..
#
# Se
# Tidrou  otht pit arstudetdtire yor: The'n. vind, foudad, itipsids wo,
# Wadus, ond ardiR
# Wit thileereldss yg;ellip tot men
# ----
# iter 900, loss: 78.671011
# ----
#  uscelar dae- thout oJ ith musher wh
# Vanky eans alo cyoY
#
# VMANI
# URIUxGUOCIUA:
# Se'st wa's La pevendang':
# Cot tres f tiusstn:eSealliun somen
#
# Bour,:
#
# OX? Mh
# Whof Sceve
# -ius, le Sond, bang:
# Tote
# Cey wid
# ----
# iter 1000, loss: 76.776681
# ----
#  Al'e,
# Hue seghe Ralo thest?
# He!
# Fheedst youve
# Bf theadk youd th iln ond fotiue he tithat bo eagld dou ceh uoke to weco'lhet theo care .
#
# SFius, have urty trerrsus Mere, that, Son.
#
# ont erave weimle co
# ----
# iter 1100, loss: 74.753010
# ----
#  eethido dllerl'dy, foJh forlt,
# I daskire thtr,
#
# MVALARNIUSIUS:
# Lale gaale umiunly
# Beve's
# Lhy the shanes:
# Eol thee ,huthrel aromer for dikitedire ton lat she oucl;
# Hodl Coake soxs werh bees not, mare c
# ----
# iter 1200, loss: 73.033454
# ----
#  bat;,
# As thlt Thind,
# Wham apd alkt Magh uan, thro ime hitsantize ss lat miat th prounh Ironmas.
#
# MMIUShIUC:
# MoRfore m!
# Peich tey Cofroust domiceveR!
# Siy,
# Af
# Wee' ndan Rowy hesttisin woon;
# I Min Iaclav
# ----
# iter 1300, loss: 71.463300
# ----
#  reund ytast sald moren -ouat tinn tlent thou,
# CaMlim tor thein bemo wich Id ally
# I end sowo hy, you ceolt Mare,
# NonI you for vay howes thir rous all siat pourt goxo sow pen wyolln to.
#
# COLaS:
# Drate io
# ----
# iter 1400, loss: 70.218155
# ----
#  ss
# wh mallerole nk bog veriund mild pratheass,
# Iy, uforen ofes anor natas yon Ron wind th, matu fhall alistiof brop ptits:
# Thas non Cormaske te ypt ang damle gelwidasn'pand by athe kuingo ceon. bancon
# ----
# iter 1500, loss: 68.817027
# ----
#  hins fimiof you sinkes, ay mae outheend vave hombemurd socont worcoor parerad fonrouer you you
# angerud mevat somip-ores fof cave toursing and whalind alle:s usce;
# youb cowelall anghen: foo ongour rfey
# ----
# iter 1600, loss: 67.689819
# ----
#  y,
# Tuere s pan he dooberla webe cor haif ceits
#
# Vind thegiche in
# Wfive oouscicetcaucius dous whath cowaveid m kbe wito, thicedry thabt hhathef, me you, you horeand come. Irg
# Ir s;iius ceale thtrus oni
# ----
# iter 1700, loss: 66.531775
# ----
#  md
# nole ustrerst ao thie
# Ou percualcach thes the, in I the ghe an ghe,
#
# i't thmesein,:
# Find oVO the rersuned yould.
#
# OLANIA:
# Hed the one nom, Togo wimy qfost; lhiveicor's atincAs ily fpifs,
# He widt on
# ----
# iter 1800, loss: 65.680794
# ----
#  ses, the.
#
# MONERII
# LUS:
# He wall
# nome hutith herms atkwors and hashithseS: fougotes's te womt fore chat thahl tfor hicbe.
#
# MMLTUS:
# B, trhome
# NI veawbens wrif re'ruast hors.
#
# Seprit, yool erdey keiut no
# ----
# iter 1900, loss: 64.596406
# ----
#  irye andikent, to wave of ald thos the aco the,
# Wor.
#
# INIUS:
# jonln:
# Th, roino hour pearl
# Thend face he
# Msan foflad benoy he pot
# y mifyires and sow Meby yourt tor hey for as of and
# me teef worme
# Whar t
# ----
# iter 2000, loss: 63.787179
# ----
#   porvego forde-
# ict I ow Thond they with!
# We the keoble sundrenthen med,
# Ir,
# rove slontes hiunce patly s ofrete bamur gom sest menst ale bithed ofelrsey,
# Mes s temum dint hay ut tbe atfer tistod sosen
# ----
# iter 2100, loss: 63.128247
# ----
#  , hid Ha dored pstitles for tore: terut at pamiti ththeade: if the wo gee sleen he wailcer bo te perenay fore whe shir onles,
# Wife ve thele ullsom th, bly Ad we the tours to inqno beeran or cestid
# Pe
# ----
# iter 2200, loss: 62.141275
# ----
#  miughtas ant cojes oue'd gos
# Ti, ut soulser you theid sy ar hite th: whak citond yow wore werut tiriuut to so prell'y, hend
# Whey ane the hove noo!
# The bly?.
#
# OMUS:
# All setil. Core beade fel tort, ave
# ----
# iter 2300, loss: 61.581378
# ----
#  that she tom simthith:
#
# io es ir bove, that Fant youre I wirem:
# Iod on son iec wed thes pocavelve dort, toPr bre Cmunens yus hes fir
# Aurg: Fi'm wo defo erone sincizend Cat th theatr
# ENjVCORMANUS:
# I yo
# ----
# iter 2400, loss: 60.715399
# ----
#  kenox? foris
# IoWy de. Round
# ins yiuns: do Rom shers hit ofirss carwis ands dave'nd
# Whan3m Cimvas mins; ollte bre sondytusg at to Th isk oursed th whath sunde soith.
#
# COTik Cowhof you, him femang hiud
# ----
# iter 2500, loss: 59.948784
# ----
#  antrad ard Iy; Cis por ait'd your ded tes tot clourd t.
#
# SICINI
# OP-:
# Cice vi hesd'st unove or wive stalve llo re vave to yous bo seand
# He forts mind
# qod so kienth firs thle'ln cetedind them cgala dist
# ----
# iter 2600, loss: 59.377757
# ----
#  oul, oull ceat, ald non Cos, ouses he the discor youid and harning and no, then:izse bers of inve tetor ghotize defon, you oma nice peatizer.
#
# Fous, the roliser rabt titas, hibtor smmiped-y
# I toy youd
# ----
# iter 2700, loss: 58.846490
# ----
#  elas,
# Thes on hale:h.
#
# CORIINIUS:
# Ath wit fors wicn wa, Mlith yaus.
# Nrof ars vot:
#
# Seanm:
# And womo ale hom uita hast, on popast 'a she thald ke nom wo luaqurison? veirned Weale yourr?
#
# CBOLANUS:
# Cus:
# ----
# iter 2800, loss: 57.973197
# ----
#   y-mreruthanterase
# Wone wale
# CeAm thon ane, poecund cour chim hyist survary. noinry noy yo: peide hay, anve wo sour,
# An hione pmane solvoole hare
# Hos hingoon ant.
#
# SaRANUS:
# Gathe he souss, Whak thay t
# ----
# iter 2900, loss: 57.657373
# ----
#   she,
# An thal sithe icest in the stity?
#
# SeAcus
# Tuy that whin ill ont hie the.
#
# Soxrtlend tom fikt thecenseads nos pfigy heell un isenof sit m'stere Abe yout wheums
# Bng taysl shethe sont- co is, aroly
# ----
# iter 3000, loss: 57.329512
# ----
#  aratk
# The wall,
# To' wereake -eorare,
# A, aaked;
# Shour tor
# ge hasus bus.
#
# CI
# ThILANIizenoud wine wow pxagune che, onol peemt ay anre, lroy head's;
# Iy wareracd the'ce gry te'ist The;
# The rom shy oin, Ser
# ----
# iter 3100, loss: 56.906680
# ----
#  ngangs-er, ne'pe tod piun mabe of youin wheut then sulnomu, ba mako
# Yion onhe the hosh the.
#
# COLINIUS:
# Cith't ie hibeday ruper w thef ar,
# Woule hente boforet, Phe frate he psigit are rous nasid he tha
# ----
# iter 3200, loss: 56.384725
# ----
#  natce wive alk ans, ed myod todily la on, ton fonct bond  ones and wicet' hitrad ald bot wer'treroul, hast's foul, shoafald hat tobe, annound han?
# Wey hivenen?
# Nuy cose, an sishave! fian youl:eny.
#
# Vm
# ----
# iter 3300, loss: 56.089928
# ----
#   hi'.
#
# CHIRIUS:
# Of ked wart pors at domase fore, theave't bobe hin ane-d
# I math.
#
# MENENORUTUSIUS: of khick meminuince plelomeed she choue tor.
#
# BbENENIUS:
# Of tha
# Hes, hup teith, lom.
# Th seosl tid hay,
# ----
# iter 3400, loss: 55.605449
# ----
#  Thruls trit laren
# Wuthe buecI grengape thes thar thims
# CUS:
# Your.
# And
# Thour bfclly, gake war snoce y enci'st ing yeeere touso? Ben pofur; iney?
# Be s?
#
# MENENIAN:
# That, art im.
#
# Bs.
# Atrincs s toll; wiss
# ----
# iter 3500, loss: 55.297871
# ----
#  , meawant her'd the te weamleA,
# Thit thath gremabnol,
# 'nce aol!
# -V
# IUT:
# To'stes, my whabult
# Thii se tie ha thesid mow hi kence is pid'y lent: has my wheld rove inn the parcof
# bas leatense walm to ly,
# ----
# iter 3600, loss: 55.247837
# ----
#  NANIUS:
# Hence 'riger got apaw, thour yous brot tel ofrrs
# I is musthet
# Whe.
#
# Fibiuthid havean!
#
# S:CI hy
# I wulls.
# Whest.
# Whem- ME oolys, haag an th hara citar 'onen he phe sullne;, in yof forienor torec
# ----
# iter 3700, loss: 54.938366
# ----
#  er,
# An with orite he shaT ald moree: beers thbit,
# this sino hom fele house se
# Your.
#
# BRRIOLA:
# Ses nigf thin promases ho chan, the be,
# To
# sacebind, mibeily uruthanN:
# I do th iois
# Lraye: is sigile sond
#
# ----
# iter 3800, loss: 54.585206
# ----
#  t
# Ind beally.
#
# FMas, lost ay
# A's, dath thans thon cous sobvank
# Salo dy. Wisheld mathe?
#
# COORINIUS:
#
# CANeNIUS:
# Tstitprs
# Of sodod in ta mow thed no mand thas mo wive danveh os, fatale chile inneive thut
# ----
# iter 3900, loss: 54.564764
# ----
#  mor Meond sreat ate thet as mape pitie, wath you siln bome sheon frome thaw oflr dond nabrat aem: eeeque; dond lall inos fry.
#
# MIRIANI:
# Ly weraWibe hay thes bay,ame fhom the miBte
# Framel hike y sere,
#
# ----
# iter 4000, loss: 54.265571
# ----
#  e, th yoe Iur mathearvey ane tile Yous wo ney ungy?'
# ghmi ,
# Iuf.s enes drveithaces theve, thin andtd yomo luge hie dethel nay 'evith th dabesm in ay,
# Thoul.
#
# oon al ave dsiun bat.
#
# CORIOLANENIUS:
# Way
# ----
# iter 4100, loss: 54.070689
# ----
#  ave so, chat wow!
# Cith buing yof of steence, ye'thne womablicetis sive Rop ouSthe ben thati;
# An
# Theqher, I hale fors.
# NBml, you have doan tbe shative ffikese.
#
# BRUTUSI
# OLANUS:
# for;afoe, ane than ses i
# ----
# iter 4200, loss: 54.180236
# ----
#  t Inde'ct Wofilgolld you gellded mant yours
# Yor be themes urvellp them 'eh: Ser thee.
# Aullligh:
# Ane,
# I tom sowip&.
#
# CORIUT thy, erstist rithe, dlees linond woud folne thend mate fome sonetis bhat thav
# ----
# iter 4300, loss: 53.855962
# ----
#  t wand iat gakeen beld fotl, de cobast hulle: thees ald boo' bop.
#
# VOLORINOLAANIUS:
# Wherie,, in alll. whyou,
# Theen:d bue fure, wore my aror watpo iend ibttlive geat, whervy aid thand
# of dy's amdble th
# ----
# iter 4400, loss: 53.896242
# ----
#   thy,?
#
# Voqus nom frich tho mithe nVib have whid: hemingor, mior Iole he prathur I mo pows wy re wathours
# Mels vare have.
#
# SICISIA, Serene.
#
# MaS:
# Hevest onk
#
# Thicdinghe grtibe, in novinn:
# An
# where,
# Sh
# ----
# iter 4500, loss: 53.947501
# ----
#   pake relas inges:
# ral.
# Yeud teneyice il prester sy ge trieldes; ho then in acpeas hat enowh the sul nsmicw, I; wh rrtik .
#
# BiRUSprincours! Ank
# ThOt thearo chitllon shat ns, you sheakl dey;
# senis hand
# ----
# iter 4600, loss: 53.914386
# ----
#  ren, whith to eakeld of cowiel wawha' sith! es, fak.
#
# TiThind mas buve, worane deve munlt! Seres,
# The I thas
#
# MOvending tower'ms
# You sta
# Rod: Row she of yeld has ane fimit.
#
# CORIOLANUS:
# Gavistoull oo
# ----
# iter 4700, loss: 53.838392
# ----
#  oll vy s awh, me hime, sserexnole, cout ense thes goms heintine and ds bo thene fin kenangond Seregalsls, I wartoun, hevelvel in Seread my ge formnous stis 's andis'dolld the ceye; byt se thive che er
# ----
# iter 4800, loss: 53.726139
# ----
#  ' he af latedale,
# Thand heme rom he boco dite boond, ars oof cow' dtheth you.
#
# CORIOMINI Ie ris, whalcen us scanl Vow spon thave sus lave our aretr
# The. hem as wo ef ren' mepy.
# AS:
# Thom wepmint
# Wey
# An
# ----
# iter 4900, loss: 53.756622
# ----
#  et as ares.
#
# Ezerane andil, shy mowh nath, eor avine ulleA,
# Aur nite:
# E'muth? Dothyign'nd yat!
#
# RaOLALUS:
# Go we mich Siss areas an in'ss ane hiThie of him toarist Trois mam:
# Whalds
# CoTes tilinst a'd a
# ----
# iter 5000, loss: 53.710901
# ----
#  ion for wave, nhe, lake.
#
# SIUS:
# Peust at, youth are cie, be I mank
# Freed ho thecche.
#
# SICINIUS:
# Pwhicn chom?
#
# File wermind bume nese haterswen bfeas sace doil: one fifit ur dret--Cy ave
# Thak rould the
# ----
# iter 5100, loss: 53.691890
# ----
#  ishe;
# Not io blenp mice ondinos is Than:
# Bow in tot to warw ligh is wilk wire lal; hile hald hurisgo'd I.
#
# CENENIUS:
# That nou noist he ondcat: wo tal ir's hascechtr the beame har,
#  owr iundye: ie toru
# ----
# iter 5200, loss: 53.491205
# ----
#  ich they minnet lald yrue thee,
# Wher busllleses yow sor:.
#
# MENENIUS:
# Dod po! Ther,
# No qoutr?
# Niy traeller sichef iunthy ouy andsir cocy so fet hiuso.
# Ukey uridnne ie andime bendmy be you, doter,,-I
# I
# ----
# iter 5300, loss: 53.500289
# ----
#   pere, torem
# The compou! Atr Res
# The, ghyiun,
# bounely la
# goo he ard. Roble, y,! hous you hadlthed how Made cond may
# E spatr is totbusthe and to for you maturoud me trow ofrces,
# Te arnteou?
#
# CORINIUS:
# ----
# iter 5400, loss: 53.524882
# ----
#  catezend ther manse's soate'd on alis, ourstronzt dive.-
# 'd thour's tryo? cheirsangto and stith ho sues thible shal, ynenaid I mofich the as woun mo heis mave mixs on
# you some shark,
# DyU shacus
#
# CyOlz
# ----
# iter 5500, loss: 53.751963
# ----
#  lr ol. O porestrret the oud:
# bre
# Tues, ar pof titg, veich's fore vene got Roust, Fort an ay your,
# Tald foave thour noy ous, mi cilt your hagh,
# Hes ooura comenares lirlant.
# Noul re.
#
# MENENIUS:
# Hipter
# T
# ----
# iter 5600, loss: 53.730211
# ----
#  y,
# InI has ragk wone angs bat thild a defondy; arce thito thut be hak. I ous nost-Ofars, por tuth thou bur my tourour:
# Host. Wo and kle hanue;
# Sene an's thOur bey as styand nowart widins cerantis thic
# ----
# iter 5700, loss: 53.807508
# ----
#  d heme, un oralfatnes you, whit yot uthercingillr?
#
# MENENIUS:
# At you be 've ordoring he thour torthaw rayy uoded hoa worke;
# Ancy your:
#
# Ti'NUS:
# beritg old hr heon hald wake wilu,
# Whary ass in angeavr
# ----
# iter 5800, loss: 53.789413
# ----
#  rush waved.
# Yaw woust;
# Whe
# quradengass dholis tole day.
#
# SIMI gly veot
# Dour moue wolle his ingis were, the Rot Theroferithe poush fide irne.
#
# Syear: chese. Mnteng bos of sonde?
# To that, ther:
# Ain aple
# ----
# iter 5900, loss: 53.743538
# ----
#  kest; In?
# A's to nond lactuadone:
# Whour ars
# Mn mwien yt,
# Wh ha movi tith haplich ave te said slatl humcis, Thrtint he lorougorer wive hes,
# Tred;
# oor tor: oup our
# jome hime of thum chacle pelllr tiens,
# ----
# iter 6000, loss: 53.831469
# ----
#  theres thald Cove ef ruble perkseHad dibe him
# Hese! Forllocke, sthecirnounSsren their t Ind to he the ceave thurintere; ang or; grig.
#
# ARUTUS:
# I ere
# ies
# Serakn enoll reme,
#
# CBRUOLULANENIUS:
# A'd hu cou
# ----
# iter 6100, loss: 53.700447
# ----
#  ,
# And margim malls. Seatk him
# bhard your'd
# ME
#
# MENENIUS:
# Oh noun mave of the thow
#
# Fit at em boddo the mame hit darustran to wo eraving
# To. I hers mongs sida pountie
# Ny
# heceriusnd.
# Fir. iigil the pars
# ----
# iter 6200, loss: 54.061125
# ----
#   al bend lade key the cficemgrake wid,
# A llve tof surt aw noble.
# Lols ard the khea, kf t one rat
# Tor thours
# Ang, End te to perom uprit at you lad, theas padis?
#
# Th
# LUPlx;adrithe bant the aaded ly phai
# ----
# iter 6300, loss: 54.455870
# ----
#  tinf him hur vile as qut den:
# Wencien louf pak co therthed,
# Thoald to th 'ngilnsy, gome thes hae,
# Bat le,
# Mor oul
# Shime of thal youre;
# IC
# Fogllk, af hever thin: I I thoutll tis nos wire, ant, thaseen
# ----
# iter 6400, loss: 54.831788
# ----
#  hy the the thy wirllsing woul, in burd to tolle coule:
# Mel them!
# Gus u the musk comter towell
# Thin macsorstly then thilty and wome, furnof katenh tray y't dead to led,
# The spesed romm, worlls.
# Ne hit
# ----
# iter 6500, loss: 54.952711
# ----
#  r chiot of that in urichy vis deceforesent,
# Wo hitu fold ho as our, ;
# wone hast ol the ours the warmomltald thald maveero dy eradme thol the, thes,
# Thawe he dowh, ruld sfors ther th hond the the pitt
# ----
# iter 6600, loss: 55.082247
# ----
#  e bin then gran tean mes int oubl instir.
#
# CLAUCLENESs.US:
# Ese hion, cedefce achauk
# Thatt sh, fore you mover noog foy dhan, salbelinn andot thic.
#
# AENE:
# Thy sthet hat youn thou dhe deenme as erte frie
# ----
# iter 6700, loss: 54.866402
# ----
#  r leage pithen, hengur hot
# com govead he why wqout
# File mikint, tering inenfricher thin theady t you sees, not ilg,
# Hathen
# IA laveatsy
# Thech thep hist '
# Roke toisencktiy ank, hit thit whil hiof noien
# ----
# iter 6800, loss: 54.484737
# ----
#  latu de whith med hop hive sud uo cos dourthe pongseer'nceatore fondy y eireper doe yelgragh ousto fothi cong for thyut no uthour ie klim; all
# wirtee th fedth wive love thin ta sivy in pare homblr the
# ----
# iter 6900, loss: 54.063584
# ----
#  tw and ghe eress Cimhy for aregtrang aprellly pood,
# Aruse'sus for a in heming, hengeld tiss;
# Irer dich'e, Whace har but you goun he, no,
# Sf or!
# Bccid meverel ragenslanoresthall thoces, ly fads ford yo
# ----
# iter 7000, loss: 54.480888
# ----
#  OLAUE:
# Gud gomaingo'd in!
# Thove su latent werecus,
# Th his shime: hill to menod?
#
# LOUCESTERTIASIEw I berees be eatr I eldef I yot in cade gads notiel npey:
# I Kikbencg my hiter chevid
# Inur aw com fild w
# ----
# iter 7100, loss: 54.646910
# ----
#  ot, ie thme the caty ond mera tad bervent.
# Oh your mispaswict yoll'd af he thesw.
# Or, ghease sigh,
# Wher mit I or,, Gom thys:
# Bulll homant as ka torene nonce shes, migisere: dor ic ofgry unte by'd whit
# ----
# iter 7200, loss: 54.592731
# ----
#   qued sueso breod wh ksturvest GLall bing-wered ingryou thee th.
#
# ER
# TQUEETENzlMATETl-terigyace t the deAblith 'ttat, ke.
#
# MADETE:
# I llod?
# O raklo wpat tleacr Mid and he.
#
# AMES:
# I thou, mell sop you d
# ----
# iter 7300, loss: 54.456031
# ----
#  thoud thaule-
# Lie ded?
#
# QUCER:
# Roan than yot rod! Anded Low Titens cou eed
# Hpicuse gae stare wive ond
# Wher bot
# Sore, disis mar,
# Be aug cop
# If ky ponuve in crotorne in ters aozrtand misswisegrd?
#
# LEvBA
# ----
# iter 7400, loss: 54.378780
# ----
#  oro maid kleve sis sport man tor pom atersofeakl savels thee bo thath thy, dyou:
# Whea dissed iu pigndhe by avenr,
# 'LOUCET:
# Wher lufperstefor Iwese rot doreserel'dire theatnour qus,
# And?
# Of is dutithot
# ----
# iter 7500, loss: 54.195799
# ----
#  LOCGSTER
# ACEKTS:
# Rerge the wall eselifs beringpld as fon now an in meld viou, our'd ouryselr dot!
# And 'f an sto the coinis
# Sheroue thast thet my the agfor me anast aof med oul haver the plotr dover
# Bu
# ----
# iter 7600, loss: 54.051060
# ----
#  twime fot.
#
# ERERUENUCES:
# Le the watheld uinge, tyot, thould mad anve thy hy; lo. OfoSt titecithoul datue thea gocly, oud doth mad aTr towt?
#
# CKIELEN:
# Sawhet
# Toble destud store boul; I goay e hart tutt
# ----
# iter 7700, loss: 54.279570
# ----
#  ER
# ALERNA-
# CGGIEN ELOUMER:
# Ssith I drist ofillbe,
# Whour maon a fory Mimer dist hat to thanno.
#
# LANEdw:
# Serienim pelof heand 'cges he eir vened ant peerpess the as nte trees awler on,
# Whan In me qupera
# ----
# iter 7800, loss: 54.437526
# ----
#  that satr tho Mivinh thas in ie rerve I an harsus what thy ionreande, Buy maa Jupser,
# Ang mutriti hith woad trtothin gowerthend bust anget, fon ip out, teses:
# Gressud fon than ute houned's ind macregr
# ----
# iter 7900, loss: 54.400856
# ----
#  NUS:
# Harducr.
#
# houl oulthe bus so hato he enogene,
# Wpaningry, muse fiw wod, bre the dipencers it dnownslle old
# Af preaWe hoo, youm tham con y bie to than huve, ak
# Thike sirer:
# Tos if in inngrer.
#
# FGro
# ----
# iter 8000, loss: 54.076022
# ----
#  es igild cius bidy stoud an er:
# Whearse shtee os,
# Toperly, tis bur! kas in you werexgooy me yound, alj Iedeen:
# Whaw andst, erie so thin hake t, bund ket My
# To hup or efore owhas iud ke to swo wint as
# ----
# iter 8100, loss: 53.682485
# ----
#   lith whers: I nome leshis.
#
# SuUCmAN
# AFEd s ald is minct waver:
# If Io sige so mond's?
#
# VaRY vipe karam; your hasse hat, ef tha deeldou shestirk
#
# ARE:
# And notis wie bundingeand wing thou hamberes;
# Nos
# ----
# iter 8200, loss: 53.789447
# ----
#   rom- of seand my
# So btham nade dey?
#
# ELAUCENEN, shat,, y.
#
# LAREREWUSENn:
# O dald my thei'd iky orsiy and ien: hot bo ale I I pamm Mare Mlvith have!
#
# GLUCESATh: noy to more mig deale be bo ladles; mot-
# ----
# iter 8300, loss: 53.821356
# ----
#  hato ly big wiranqund you dade, vey ike
# Tir!
# He defor.
#
# CLARE:
# All the treaver dothy y
# Uingrth will wango ghatr I the kel buml of mave geave wire, pain-;
# Nom fam in that wher,
# Ko jow singat ha spoon h
# ----
# iter 8400, loss: 54.044166
# ----
#   Ipathe hy.
#
# MER:
# Who hish thee he bris thow
#
# AwUClEE:
# Angecuslcon pread the hy:
# Ton; wicgas for ly prant tream m Be that ougnd aist janave uf! fbe me will ther cosen!:
# Grengesk.
# Vin wishlached stis m
# ----
# iter 8500, loss: 54.275048
# ----
#  ; make,
# Bet the lfor for co abdther cow in shon't, heain your ur ctit in kyou shat ordthe as werawhy.
#
# GLIETW:
# Chetsere thas: I ondin, I gios learuls hish thoy gramorar ut had:
# Dhilt and
# Hive whitham
# ----
# iter 8600, loss: 54.351560
# ----
#  myme,-'
# Non, ards storeses thesn by eied fequlldes oul whalf beor, the gintht habrwis mict, yer,
# As is luring tha ceeand pleeyda dem; nodsay I co of fir, unis
# Angum' deat ilcink:
#
# QUCEvebly noure of l
# ----
# iter 8700, loss: 54.235891
# ----
#  hy ore thour wirts
# Thems
# GSsy himint now sus tims will with memor, anc solr at min benind
# Hithon:
# He, und I, by welw; Iut! I mis waizenll of ty toon with.
#
# Shed semang win yousst Cave my ao lasce for
# ----
# iter 8800, loss: 54.257796
# ----
#   deithsee nou, so bleaver kinfer hou pestine.
#
# FQaCLARH:
# What' And
# A'd for now, wame the she by an foo hir tha Mlallicud-min''gnoug Got ourdefaoween;
# Sinsenf Weanses.
#
# LAR QUELOUCEGYOUSI
# BEMES-BES:
# Sh
# ----
# iter 8900, loss: 54.402372
# ----
#  o.
# Whancers mur io chye aws se not grove thou stie hepelzinto guct sabreish the he prstold that CFithenoug, sowclo erisse ma sad zaccco soby, deonil treigisce hat
# Burnward vaty in heath ther: whact,
# T
# ----
# iter 9000, loss: 54.278071
# ----
#  e salmard.
#
# DUCKRINK:
# Buld hit hato, yat grueed,.
#
# QUCLUCER:
# Whit, ofes the thoul sofor wail mlatr:
# Nofil bow we to you oull'd so thesies:
# Groved, gouthe yoe,
# Ins the hare a
# Trece her blarerseen in ma
# ----
# iter 9100, loss: 54.085811
# ----
#   tha cow auds, remare, bey, I our th:
# Hy couk;
# Ke pus se, roll
# If bedd fare butiur and cor thot, mach ther.
#
# OUMENbD:
# Bul bes nou, manen Marvess thyo.
#
# OLACTEH:
#
# DyOGHAR:
# To noust neamast.
#
# RIND-TETHA
# ----
# iter 9200, loss: 53.540354
# ----
#  llw.
# A fof geale:
# And noas;
# Mane.
# Hatheld unnullous.
#
# BUCKINGHANY MESYIZ
# OFIE:
#
# RIN hoo thot dyas, ules yat lfipn:
# Tither'n, sobto lord maresstris moor st mev siny mow,
# Whean Wate hos heAl in in sorsl
# ----
# iter 9300, loss: 53.482209
# ----
#  y ly fade lood'se
# If ae mord th yel: of andtr:
# Hend!
#
# AwUCEShIN whit th inclide no cous suprale me?
#
# Youq--our, and mandous,
# meakers, houd readtte
# Mery hew;
#
# GCORK:
#
# HAOUCES:
# Wild me dorcuss?
#
# BDUCHES
# ----
# iter 9400, loss: 53.374702
# ----
#  n ptot shint youk
#
# GwOLAICHASTWI
# Th:
# Larly youer conder lath, oo lpase thour:
# Wher.
#
# GaRK:
# And that that you sseest ther gom, fhend me Cane, cail touch, lint tover, ithart and to yem-fooll hat to chas
# ----
# iter 9500, loss: 53.164411
# ----
#  sheruse; lustavit.
#
# IZALET:
# Gacisconsuncler'd ieplofore,
# lo llmo dee weed?-
# A
# HADKCINES
# ED
# AFUEzTETEN?
# MESTI:
# What be, shor.
# Whims unigh ave Hers nod yous y
# A
# NGLOUCKINGSTDSTETI RAKS:
# O min, wit to jo
# ----
# iter 9600, loss: 53.176256
# ----
#  o sere, no grarde gow me wida bes lousu I mus gard?
# UTire; ie thelt so dyot Githe his y'vin stite dare an wise If, Gow hard i mowe woldde hice for a dowit,
# Thimn urncetllonch wams nor, I,, hour. grGte
# ----
# iter 9700, loss: 53.099579
# ----
#  xourd the bas lrram ard neecgor by mare kit; you, the, in thou,-need my, lost'l thes;
# That,; brate in bestere
# Cood, daseard
# Hane'd blouterst uvunks as ies Es:
# Ros.
#
# BCHAT
# AT RER:
# To your! Passsarat;
# Y
# ----
# iter 9800, loss: 53.090909
# ----
#  stome frease ham.
# Wer, nouse haklw Hackinged, be ceod liog.
#
# GLOg IDNCGSTYOOE;
# AmASLINNKaSsenot I me.
# Lotr;
# Nods.
#
# CKtAR:
# I preed noussen:
# What Yinars you fenath I as, wist wond,
# Hit stave, by at CF h
# ----
# iter 9900, loss: 53.057619
# ----
#   sot there, bearst;
# a piterrr are spoucs, of thime thal blaveser sor?s
# Ards, On sit was;
# Ardstas gra thed you by cady I heato walllond the theed brtis the in, ardy,
# I'f you moble the to sthind.
#
# Beved
# ----
# iter 10000, loss: 52.969844
# ----
#  Coor no dowlith nilist't I in'd che sow.
#
# ARER:
# But deer dongem, thit
#
# CUCESTERESTAR:
# Forder,
# And frese are ongs, lover, wis, wis I lares mlllerit ne yusbuth ford!
#
# GLACHANNGH:
# My avell tot ho kart,
# M
# ----
# iter 10100, loss: 52.912517
# ----
#  And mongs,
# Wo tit kenge?' Cquest if doper
# I'd pat'd'd acces sitser he, grarond kent,
# An touge,
# To in yiy y
# Tha seatit hath, aver Rovore! masthe cheog beled,
#
# M:
# Angin that rome momigh bast, hopror ber
# ----
# iter 10200, loss: 52.896553
# ----
#  y,
# Andp
# akm grif coteen y, lont to mich my has tere, wrim gatinU
# And lanens liming
# Be in of t,
# vie coper, noup ald foofes affarenofe shale deat your cowx!
# Be tainck
# A,
# Bunrunt, sugritt Gomer Make.
#
# CE
# ----
# iter 10300, loss: 52.934367
# ----
#   lord;
# shid if im hy co our havend weeN of oF tus, the bougringy,
# Wigetile.
# But fie thouldse;
# And theyve,
# Gue nor I sove, arendat ay of litpiungut.
#
# GLOUCES:
# The my pondery.
#
# CmOVINNGTBMASTGCDOUCESTER
# ----
# iter 10400, loss: 52.800075
# ----
#  INThen, bus he tha munking:
# I cald suthe tollor thes sue thay har'e I anchen minclir; doGl, nhe, dacp mome mald thin as ther my pomay, my go chepigst
# At erst larmo my sti whince I thay, hy
# Thay wile m
# ----
# iter 10500, loss: 52.804926
# ----
#   so hent, the fereraces
# Lorce tith, hape, wick heunes'dor:
# Seiricase, beave ay tllood mevelroine a
# Thhis boke farlizend, home ft the my do thllprad, To, of haWlams;
# I, mom that this atd pook syour.
# Un
# ----
# iter 10600, loss: 52.991092
# ----
#  e. Ondy an te wert mis mors not, ras dathisasterect tood of cistitigr, Leon wath wall to me me con wome.
# To teatel sudhe my whin if hame theme yut wherd te't our inthe martads peime chas Ciro cow I mo
# ----
# iter 10700, loss: 53.201751
# ----
#   sed giece poy me'd Er If they shou iy hit our my thof that wore:
# Are I ie Ifarnerase het herd:
# Why the a slounts orseose-dey brion cofly robefer!
# Disctblmitus, in I warde, them sofes farle OH:
# For co
# ----
# iter 10800, loss: 53.041371
# ----
#   us tise thet pome thith hard rasbon,in'l seniel'd bhald podeingreads wan t I-doukize bize's ay cive Lave
# Thoune, foles Iir sare sepn, me tham bupe we noife!
#
# ICHAR:
# Go,
# lovetent talnge to buplly his
# ----
# iter 10900, loss: 53.165304
# ----
#  nomenthe ryce tiobron his ta the wlarmant wigen:
# Angon comest my prampexoodh ingho diot ay
# Ted sed savt fros in ino goikish vorat, of ceiep!
# My macooe tlisese now,
# Tot pland inchwy wangiss gratble ure
# ----
# iter 11000, loss: 53.457078
# ----
#  th,o tham jourrs benow
# Honchecl ghaswvefo that.
# I ofos tit ther y mo ao te? 'glo fablimnen hack lerenotl obretearom fround Fhis I fucllns te ceis made, me thav wion vorl, mo the jeake the platree,
# Tow
# ----
# iter 11100, loss: 53.541956
# ----
#  thyul ford, me hirg, vonk
# To gowhaw:
# On in eriere forlish deer bure mers whised
# 'ndwe wose nobeads thiss hoom.
# Mand Tyol uland!
#
# QUEKEz:
# Lore Ifed thour hes, the copendeane w
# Leads it on bleay, yob hi
# ----
# iter 11200, loss: 53.300710
# ----
#  to hood
#
# FLavin stoud you! oud thoub tim ssee an theath all bicher.
#
# ESsfor
# Thor dyenthat.
#
# GGPTICES:
# As pacjanto mith tos oo unace diss onde my of mrack
# aty the? ducy toul of ence, for wyol thy y ove
# ----
# iter 11300, loss: 53.090489
# ----
#  End rath is ape ang of bustr;
# Ther thae en these it me pcerinmfad ond earnnint bome of stat olr'd sI stound the thace Chelest's deadtyou giss prenous of Erdne, kvie all, soc turete, frout,,
# But that o
# ----
# iter 11400, loss: 52.722796
# ----
#  I bloclous Rqhime!
#
# KI EHINIZ:
# They hime;
#
# ARKING IET:
#
# QULEM.
# ODHAUFID:
# To the troul hep ther yat ted migh tee thby mowerse inen bes yof ou hid
# Wak aF hite,
# Whater sonle foren to t?
# Ma palk seach tao
# ----
# iter 11500, loss: 52.134870
# ----
#  GKINGG:
# I oy 'ther senst Yally wey the gearto tame of lyof hath thead ave to he; foile grale? Bur ho spyor thas mill the warter tha what the thot to dar, soy the treaings blie blet,
# To mer; ave ule sa
# ----
# iter 11600, loss: 51.979302
# ----
#  but.
#
# QUEEd MES,
# TKI ELIZAEd;.
# Oe whalt'l sadmoZs
# IPll mopr than nfel theso and, I weale's
# Thef qutien, bistel.
# I sas hin to marst your bhe tived,
# The kwatrer im pabl sows siget fay gronivisuss,
# Then!
# ----
# iter 11700, loss: 51.375679
# ----
#  l thed arl thy ract, lome,
# Ango qut thee hevo in sususads! hale, kacvemn srderms't coo my all, the peaave pnot theur fall yen by bnt mer aks listy, theer Youl well tramusmy'd spame thing uedeer, I bun
# ----
# iter 11800, loss: 51.350166
# ----
#   I our las, draa doult fofere noe hor at re to buth, me buvend heant geosh.
# I glingws,
# Acl woresneood it fop to waintefrelarts .
# Nf molqomo weale neesse pucopee dore the danm noy and ty ard mo ghounee
# ----
# iter 11900, loss: 51.252881
# ----
#  how ay and ts sof sever:
#
# KICHARD ID:
# Me the gieta mirch, RoR:
# Wow him to day:
# I thend;
# I he gientafeinnkyrd, bot Gome beth to! his?
#
# KING, -LAswords, Ivoon in bevshol a the thour ip he loversisge,
# Si
# ----
# iter 12000, loss: 51.734992
# ----
#  han Got: is thiJ.
#
# KINGu feyse of'ly my that tor, mave
# What; theay
# Thou; oo des bawell, Ancto, ble! nivard pall ond bray the dore Raverense-sid, whell.
#
# CIII:
# Ot sin, ay and thes cit-!
# Nold dear.
# Fhou
# ----
# iter 12100, loss: 52.110751
# ----
#  s mond tie bay thead not!
#
# DRICHACHESHATH:
# The tat of non in hath leavy aikel fning'd Coore, our, why mishead if geot.
# Nor, gith kinger I tot fome
# Ant Ed wey to ma mend mordor
# Teate'dvith.
#
# HATHEH:
# Be
# ----
# iter 12200, loss: 52.418631
# ----
#  .
# Surss nard tay
# DoPd to cource mis bain': thon list chithmunt my nogste war meplliog.
# Coy shay forle ormisest And ored thtat uen I theares yol the mered desty,or tils ceardishist soode ogo leervenom
# ----
# iter 12300, loss: 52.526896
# ----
#  NG Yit IDNCUICHARD:
# And me owadder quared thll sfovere ant foror: morgat mise:
# Andill doute your fracks, cactozent whinur ond the ogim:
# Shit will no cheor comders, tellnroys of!A ne you to''d ald If I
# ----
# iter 12400, loss: 53.020405
# ----
#  ntishin I hoon wert yom falt for nre
# If.
# Hy.
# Poom arithand fot;
# Whall wromes pante;
# Miremy a knece qut!
# Nnay ore?
#
# Figrondefeaed,
# Of tusingrs urungoe apl;
# Misers tat my ryon thit milor'd and coodC
# If
# ----
# iter 12500, loss: 53.099902
# ----
#  shos hathe?
#
# KG
# RICHARD ICHARD MANLINGig the fadd at reem Ms
# Ther dtroth theand in sisha Nilel'
# Poultte shouest He my.
#
# KING, che in hors I'd largsen an ang mich bara couch you, If shetree her.
#
# xKIII
# ----
# iter 12600, loss: 53.006865
# ----
#  ain?
# Faicherow in truedfel-
# I
# To deake, thoul'n, En anth I tulese mill montely sofult fnay to dith.
#
# BRII:
# Mirefne to will waris ad as Gotet wailirese wardgreind upe'w homas nompancood wha of Ifceing
# ----
# iter 12700, loss: 53.190911
# ----
#  ur.
# Uod iog, frot wild this iy longherd tare,
# Sus Ra'ssey ugr mos ous maid mive the be didh: ap the
# Thind:
# O demevmel ta blit, an wivi his blof in goul me ffor alm woll art the o, no mire nvist yre po
# ----
# iter 12800, loss: 53.425304
# ----
#  lots, dust the cofale
# To he I Le ay sok ind yuandarese fory hout you,'
# Heans, asd ais.
#
# AGLI THORD IRGH:
# The ie ain,
# And nove, Logt cod, thoo hercurat san ain be owh poll wyou fhuy har tizens'ws in my
# ----
# iter 12900, loss: 53.543798
# ----
#  wher, Iod thelbelm: Mor tire sant thit chandeese theey wy'd wheling po lo beforouse sotlald mar:
# Noll hotis my supee hy urg lave fargy.
#
# Q
# EED:
# Ior of Hone me ie the brenom rot tied's cpiss ingle oros
# ----
# iter 13000, loss: 53.763196
# ----
#   thy-ongablod you ronget w in? inneur mute silwous bod thougen
# What hos alk oup shousifen bangt theadlint thoune the ueins alchchwwase ff ervio ho caich'traln whikn
# Fhal.
# Be thin wyil the af bail,.
# I
# ----
# iter 13100, loss: 53.779408
# ----
#   foll hally the.
# Nok he.
#
# Dint butant slorperst louk ghithsto wist your thend my kx vivode aret, short bued wefor mighit yot teos avencing terak, ingruth.
#
# KI:
# Loulundtellestrever'd sed'whens the and
# ----
# iter 13200, loss: 53.975089
# ----
#   I cot thy sall the, swaty, doucg tound atheo lpaing,
# For nas Coplincited at, dall an pntint fecm win wisto deyou loufor, alct thon ceald wit pris weRme pheife tit for haterse me youns najeen:
# And by
# ----
# iter 13300, loss: 53.895797
# ----
#  Opkn't liseingrougla
# ToN the flatef ray hith cltove, bangd trmuns gouch apy! Eld art ma homand decin.
# Ther red tis orintt Buc my loot Mikers.
# Bacle; wy uigthe
# Me be marls pand thele!
# Wlaw?
#
# Lon merws
# ----
# iter 13400, loss: 53.966084
# ----
#  t byou And bllithard if in as kinet hy me parthe or, I is blate is whis sheprmalfeave
# Sh berous my y'd me to toned sisefem Wire of datlo nou, by by an or stous Govst?
# I
# Thall avy.
#
# Faling feede-
# Cine
# ----
# iter 13500, loss: 54.007266
# ----
#  's for Mich:
# Wonges kmon sherent,
# Hant sings lstutath:
# And Gomanpeato lion of weads, thew sciving in lade gores, mard ly,
# Godth mimen that prit brond and lonk.
# My tryou be whe comet fur in fathe stoul
# ----
# iter 13600, loss: 53.940712
# ----
#   shouce hepr,
# Th ant cong?
# Thist ay tute
# What enous thy ans yourd eo tol hancey amlpry she anneld, so-hef Loreseed:
# Tr'me.
#
# QUMEN ETh:
# Goun towh gale
# Thun IF wimsainha fores and low besor ind thyas ff
# ----
# iter 13700, loss: 53.930329
# ----
#  w, ove filheimg exsiep tis elisess,
# Mat whe tri goue fougher kent bu ase grosod?
#
# KING RICHARD CKKINf py vaus sinbe ansongenoblomsin, worothin agr horess onont the,
# Thoul he she gope, beers and, rethi
# ----
# iter 13800, loss: 53.947109
# ----
#  thewy oy urake whaher jovarda fod ae sore-hed wheF anblotishend
# ble tith you wete our hut in sie perans?
#
# JROON YORNLAM:
# Dow hearngot-hay my shice,
# Andeas
# Whith, mourt;
# And reatenaile
# Soulich her.
#
# BU
# ----
# iter 13900, loss: 53.810862
# ----
#  d'
# Mules lasthe rees kico deas 'Te at my shay tit, wing that non ne fect fore'f midmt,
# Wie simes?
#
# LI HORI:
#
# FIind'bld
# Hredst.
#
# KKCFYCuse tassers-lay:
# Yor guties fath;
# ard tays?
# Gruake: h's lasebrswar
# ----
# iter 14000, loss: 53.880844
# ----
#
# Faliguc'smt ron the; mowrAd theate breventenrip, lllarts frot savefo As I dartes and thay Got keamseon?
# UV's II:
# Medt RKU
# DOLAZUCLOVY OHY RENUs:
# This laty!
# Whom: in beath seat-waspend waunit,
# Wey lon
# ----
# iter 14100, loss: 53.617077
# ----
#  ma gy thele wew wrelerin, lisst of by ame ppakedign ursty tay theni'd
# La Hed thisk ou my and to haplen is ermen' pa pale uf and romeichmo mallece
# Fousonn,
# Whe my hiuthoue,
# Noke;
# Hotoon:
# Norg erdes, so
# ----
# iter 14200, loss: 53.505064
# ----
#  ego tofepefe wie ind olly his at tiecteed brooll thins the As Dind thy,
# Whis sard sus to biog! nos I in lavo pofk.
#
# KyNG IINBENF BROON FKING RYNRICHARO YoLeme
# Till ie ha po ape;
# Bun at eray,
# Whe wak h
# ----
# iter 14300, loss: 53.580084
# ----
#  d thy hee,, ares Deawhing jumike barant bowcewcoringnon wimo wiseprncenitr, natl woct.
# Buk thyod:
# And sined king,
# Nolluse fse cowirgs'dich
# Bu.
#
# ERNON:
# We th rearing sand ther prat And, n loure,
# -frron
# ----
# iter 14400, loss: 53.730225
# ----
#  s thim whossente hallist our he swemuwerCand Tave lave oh:
# Whe we'd ingt twish hamn to is as inse, hablind
#
# MASH:
# Wist o somer awing, son singed sto thour the beecr bpamagaving,'s; chontore ther soufe
# ----
# iter 14500, loss: 53.741081
# ----
#  ingal sfuro, the me he comenfecith, courith the wnold hake hitise;
# Hert wime hathar:
# Andho, hatk Go-!
#
# KING II:
# Herper shon ta ist an sut niver thim to bus vaTh the erers nol nipn wnod thlar mlingr'd
# ----
# iter 14600, loss: 53.739375
# ----
#  asd:
# Wis woplly ful heple, now!
#  wes fill frinh him not My uer us fwaln namers mund Oo soriNstear homirmmiogs youg theil,
# Suvod ane pse:
# Ard und smin,'n, and andie,
# The ponge, cot munes.
# To benos lirs
# ----
# iter 14700, loss: 53.851158
# ----
#  kn slr'e
# Moth beratithssur's my row my ingerand and fors,
# Whisgur, him then uill minklr.
#
# Fis were lfwert, of 'eCrer iens:
# Thy tile,
# Whelh word I worge cus, ?
# Leir, reet yol: fst besored, bunferd lato
# ----
# iter 14800, loss: 53.718680
# ----
#  e fast yen. Gow frater cqo'cos ly if innith'land of indk: shay russele, toy regnne;'s Mistin os in my ut you,
# Prearied
# And
# Ay w ast.
#
# KING ROTYKELEN MI, HORd BUTh:
# Lle,
# Soddymane ore mef;
# Erith?
#
# KERH
# ----
# iter 14900, loss: 53.552333
# ----
#  rr at our, depe-seesefoult, your, Es se. Of paser machonte!
#
# KEN MOBEN BULENGBROM:
# I shtim whoun porverre'd fly amt GO theallen blly grive limssurece.
# Harbume:
# Alill your of my
# Cyanirp my shoufeland m
# ----
# iter 15000, loss: 53.420517
# ----
#  ast
# I her't a in mworast sortm yog trencpmasthat and in hay hou.
# Whith in yea, on,
# An, ree!
# Nod the to mebelm;
# I gouth ble fich.
#
# LORN-HARK:
# Tryel, lorde entmy
# His bothanngeit onk.
#
# OREN:
# Bith neethe
# ----
# iter 15100, loss: 53.423203
# ----
#  rounenfuteer nough treod nf the tolf pringhra? sofperen tis morst is bling dislith wes ufgrcrith upe thit at tis tiod'd hoo wheed thesom cour,
# Thoufere thery, make, I ungnse ofd gink
# To horde then lal
# ----
# iter 15200, loss: 53.366480
# ----
#  ates fresstand nameen my treanth-o mamm leaver; as at me pnoundy ery hart angpe diel the the troun ore hato gatt eill thy on tarle aog te a waine me loulithou houthvat e ky
# Helt Wie sheme,
# To ceace,
# A
# ----
# iter 15300, loss: 53.449733
# ----
#  ne thainget cenoth ingn orest rithsincl of what suss frentware
#
# KING II:
# O il of woll war! or beianw oo noth fat ame ey tre brissor?
# Hlevot dat
# To wirparwd watle,
# Theaing loy tathe thy the cotons ios
# ----
# iter 15400, loss: 53.498781
# ----
#  d
# Mes and pivew!
# Thin woustles eep acy dedie,
# Apgs,
# Ak swon seiog?
# Whirghen our sore:
# Cay yousanad and thaw? I rollo nomehel, fremows if enascer mere, wallpeal tore peel and tilin:
# Me to loule theshil
# ----
# iter 15500, loss: 53.433008
# ----
#  ist thet swore with racgeard exed mistry smeast swas ors of malkinder yall-hirgher bath loon I lice blleen Yiringe fart lirlnoug tringerlly treever our theth and all's
# Ang you thears,ir dime gravethe
# ----
# iter 15600, loss: 53.327675
# ----
#
# SpaweThink,
# A pricsle aighe him be whells.
#
# JONT:
# He so core and of greea,
# The wist ulless byue, ak?
#
# is Yount lfeilccle entithy hace lestrounds
# Woce my wavertte thens bive hatl of lyom bis reded.
# Wh
# ----
# iter 15700, loss: 53.393466
# ----
#  s,
# BeR thel bots ouzs wo os of your,
# Oquey?
#
# KINRNRGRKICHARLI;
# YORBELI.
# DORD KICHERY HOCD AOD STORDUMDUKE:
# YeiXs 'o sin? as lis doth.
#
# DUKD DOICHROS:
# Th, our, my yok routp ord, or, ark
# Iror than sudst
# ----
# iter 15800, loss: 53.386758
# ----
#  ll ked gowaeain:
# Athence hit wamt with yar be yeave, my, lose Lecr inder surot ho pinishedr-too hall wour.
#
# KING LOLANGBRINGY: wild I deim he the cowl.
# That ro.
#
# KI:
# To lee court the cood the amd her,
# ----
# iter 15900, loss: 53.087475
# ----
#  oise buw why homand fforws dow an Oppeance;
# Hy greegrmun to dleardeang Iak A
# Thebet, cat tipurd, yar mas, mey Edsy, ligppotesil readsh,
# Tholf,
# Ma tay fur
# y
# My ulpelise afels
# Gom yot ere
# Ifgerieg,
# Bus
# ----
# iter 16000, loss: 53.222979
# ----
#  warll tha Plarm pralls: of ser, st goprongr:
# Theeed thou hitr I inked ow; a spattrond'd
# Boveront a antuse seref?
# Moold thou.
# Cuol naved.
#
# Ik
# Mino sool:
# Goting 'ring dave 'to whe my stinos, to suok' ou
# ----
# iter 16100, loss: 53.232222
# ----
#  il nake
# Sf dot lim't's
#
# Fyruth mas. Oher guod resverul cellres I but mink lowd,
# Und
# Bod thor: fore foant rut sle cead Iad In lanco lotor my thin thernen or antay.
#
# Ohnat? Of on deat, I rot is stlaUg i
# ----
# iter 16200, loss: 53.130537
# ----
#  y ward st, Youne geemulr?
# On pees warling Mall:
# Wwiry's, refes: kyobro lemavtw
# All wathith theme hard dilneds of ghou fall shant is in state botherel themulald:
# I wes thelR.
#
# JOORKY RINOU; HODDUOFAT:
#
# ----
# iter 16300, loss: 53.356568
# ----
#   ok, he the wy hey tod oo cam I howince that klall thatt you date ast?
#
# KSTHAUKE:
# Alct I daw wale, ball o meat lo ceatiswaty arinch baded I wey nus Ifare
# To smong anee,
# A I with tho
#
# LICHESCARD ICYcat
# ----
# iter 16400, loss: 53.351465
# ----
#  OLENLI LARD OLENNGGTI LOKE:
# Er.
#
# HENF YORD OK:
# And word to thy to af in'd and ull deros
#
# HROY YERLI:
# A geang ast frtin the of the to Wa maro:
# And rad If ne sith hyry agand.
# Thy as I I dils joDe searem
# ----
# iter 16500, loss: 53.064343
# ----
#  art trofw ourin' knacce coow.
#
# KIND EAZABEREY RF YORBy:
# Ns pemall whel;
#
# Fike ise at
#
# MjUIjThe: youro foy
# :
# Ma reat tot, gay tulive har tapmave.
# Wed the thaafen;
# Of yoade
#
# HHOLILINGBROLMA GFOLING ROI
#
# ----
# iter 16600, loss: 52.884965
# ----
#  cepeepr,
# Cay hith im ulbe were is no the ullep ame? Ratees frees'sut ceact soutefort: the than. Coret whe puestersce gode of lloun, repbith.
# Lon!
# Uod an?
# I all fo govent mish sane borrdoninw mast bime
# ----
# iter 16700, loss: 52.587509
# ----
#  od O tiy bravens Bouscoobul Herant urend aed sobringen thoul one dis
# Torc wore
# Sed,
# Whiule dedingsefery brome:ith cemi sae y, condt befie keng ay doms;
# Bus'dg, innpen,
# Tho Btyoy solarmer man bikee to
# ----
# iter 16800, loss: 52.636640
# ----
#  s; tor then not patlp min; tliso imel wield the the with tave an mese pomo duce cowe kinss,'d so heal I whor hond wire a my jomarighey rounbuin thet of joVis as doweed dry pmeat the meaph: to hindmond
# ----
# iter 16900, loss: 52.439367
# ----
#
#
# QUED:
# Who jeanes
# And ly line peall keol pleiking allo turnd toll of lingrout
# Hass dong, agl mad nouth bepale bicn thy prave she il Soter: and trins Stert,
# Hord dor.
#
# QUYKELI:
# Taldret an 'cque: de sh
# ----
# iter 17000, loss: 52.419238
# ----
#  ng, cruchthoo,
# Tuad Iorm, shour
# Nos you, And ery, me malerunalh this
# Gaknser of on a me kad aldne I ind mo tears'd thal shom anco head
# Trin you simt of bu cowserve thas seell tale? ancthu giow, ie, li
# ----
# iter 17100, loss: 52.019987
# ----
#  d eto horgt.
#
# DUKERLI:
# Talluke tat frots on miencl to ky.
#
# OHERBEA:
# The theld, kens rest
#
# OF LORD: But wy a Normeer cakear, sorther, ore malk the traget ue dod is nowhend or urdtiry paet'l st, Awas on
# ----
# iter 17200, loss: 51.696045
# ----
#  own od aply, eros shee searm hanblise ieginbm hath ooling wo to kece sheam-.
# For weat A k;
# Thelin.
#
# DUKENM:
# To,
# Thy fatse? in fook But som, shand, ustit? Sid mert Yoor in Youge tha weatg chat, my sh h
# ----
# iter 17300, loss: 51.523255
# ----
#  e hatlut; aads yoy that in sharce? therimunt's'
# Mass I hiy's gowinf in Bell y therlantror:
# Andse.
#
# MONRY BUKENG! ONOOF:
#
# DUCEce,
# Trou? vept:
# Hor ow:
# An!
# Cive reands stigutcand ild olk
# Were cone; w
# Aml
# ----
# iter 17400, loss: 51.514259
# ----
#  show wolk ef fon benct singe by veat gfor, I The misle hos.
#
# HYCHEM:
# Hentis, then shaw,
# Morue,
# Shis Andte they
# Th ma whebuther, and, infond teans brincind rester? Buly terase the pienilg to?
#
# DUCEY:
# W
# ----
# iter 17500, loss: 51.651277
# ----
#  d, I.
# Fall at anstray brow?
# Mas wis and loor blams, the,
# Te
# BaMR IUST: Sean hourser poms;
# Wo me pare oros barce Ow Ot thou hourgr dores
# Wid unging fre rot'd mins of Yoand, aigh comensean andert, romme
# ----
# iter 17600, loss: 51.674543
# ----
#  ard, nepto ho and!
#
# HENRY BOLORL:
# Gonn I
# The ky then why upli'd have urrio my foligt's
# The.
#
# DUCHONLEN&Y HAUNG OKI:
# Nocs thou hio do loige tf
# Jon ere soont bay, to ko klinor thay you hood was shaufur
# ----
# iter 17700, loss: 51.607346
# ----
#  our aint, ut withe him, havere of the a deem, woruthn thay kist, trraged.
# Nou: we to kose ow Ixef yer I and thot ma weno bake rouded; I har:
# Le in be poion conde thour ill his farwy, groy mesped his t
# ----
# iter 17800, loss: 51.928549
# ----
#  d fall,
# Hank, pat,
# The sham beybes
#
# OF HAdd, the mars to cairn borevealy, aF sto our thy bem coel of.
#
# ABdCATHSBERNS:
# Sericl that aud and.
#
# BROF RISTBRON:
# Lor-wed, my the spas?
#
# BROCHES:
# Treist in our
# ----
# iter 17900, loss: 52.319753
# ----
#
# MOCLACHERSSS:
# Wint pod hatr horin, if ay heaw, sory pron is scimeat leerld as avby antunds outr.
#
# BOLOR BONYOZIM:
# And opmse:
# Miveist seen stre's cof fst,
# What ma hive theay him in macces
# Mall braro n
# ----
# iter 18000, loss: 52.561300
# ----
#  urpsines wher ave heale hy for undeld dive nooy, hun ir.
#
# MESTHA LII:
# Whys hand? st hercsen, fug,
# Arlding werbhislly mon, khaen spigece ag, shentonden.
# Sryounoun thet, ullmering pitheanay?
#
# BYORT:
# Le
#
# ----
# iter 18100, loss: 52.599080
# ----
#  And Inato guthessing har
# Ofmus whCesid.
#
# QUTUCYOOP:
# Guck? Weich bengs dwe tisgras bormeay
# I
# Whe do giughre heade tile
# Ible fallasee.
#
# BENOBUMEM:
# Deie sold I DUtf tidse ugle thee cero; in werof iF for
# ----
# iter 18200, loss: 52.738027
# ----
#  lle I whall sile.
#
# BimUCHAUTI:
# Go hhe. CHis s'ky.
# He sies slamead ner ftote;
# O in trant lidonn mutrerurith wous I look se.
#
# LEde that amust Come hase chite the nordy, thal ant sors otrourth the heor i
# ----
# iter 18300, loss: 53.000412
# ----
#  d ald, drisher siom ow
# Iis ald wind if fas he ppis hy statay ther cer, hebld, fale dreink ad fut, I this ir thou. Com-
# nid, fad.
# Fathe mesrn, us.
#
# GONOL:
# Why chon the ba fearg shouth bus cos suring fi
# ----
# iter 18400, loss: 53.193802
# ----
#  rag I ligtt tild y benco,
# An kay thour elryeld---vool groow mave wart?
#
# BAULE:
# I'd and corenutest sad sees; cleal eravesisedh's plent;
# yit liss sule bstve in theod quertigt not whulr of the wheraats W
# ----
# iter 18500, loss: 53.340095
# ----
#  re gild.
# Thoun s, larper broture;
# Thou lood, eral gus, tino.
#
# LUUMMAMG
# TBORI:
# Aw suveng thelle,, sgaveen shiseed inoth prouls, ach ncrvese: iss use thay und is or nvom it'ling wide
# Tobk a
# Theoc hink't
# ----
# iter 18600, loss: 53.453470
# ----
#  l the Haswans
# Mence Io wourrenoun's mith an he sige the pouch whisith fikith buvingle,
# Gogo thered hems oy shoull, doy ofire,
# My the oun that Lele conence you tnye, shered ald coalperect of to liver,
# ----
# iter 18700, loss: 53.636941
# ----
#  ud:
# To ast amle co a
# Kltnte eadatt.
#
# LII:
#
# MANO:
# And muod, is noth thousiin'ste would ower doy.
#
# facrestot olry my lond, houce I thim frar, bremay, youped:
# Beepter the bee thad heanasgea ton gilt Whou
# ----
# iter 18800, loss: 53.819054
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-23c54a2a04c4> in <cell line: 5>()
#      18
#      19   # forward seq_length characters through the net and fetch gradient
# ---> 20   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      21   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      22   if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# <ipython-input-7-b6e72c13c965> in lossFun(inputs, targets, hprev)
#      12     xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
#      13     xs[t][inputs[t]] = 1
# ---> 14     hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      15     ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      16     ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# KeyboardInterrupt:
